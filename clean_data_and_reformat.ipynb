# %% [markdown]
# ## Data Cleaning and Reformating

# %% [markdown]
# This jupyer notebook is for preprocessing and converting the descriptions(free text) from detailed_description.txt and information from designs.txt and conditions.txt to fit the required format of different models.

# %%
import pandas as pd

# %% [markdown]
# First, screening:
#
# We are only interested in the clinical trials whose purpose is treatment.

# %%
# import detailed_descriptions.txt
data_filename = "data/detailed_descriptions.txt"
df = pd.read_csv(data_filename, sep='|')
# import designs.txt
d_file = "data/designs.txt"
d_df = pd.read_csv(d_file, sep='|')
# import conditions.txt
codi_file = "data/conditions.txt"
condi_df = pd.read_csv(codi_file, sep='|')

# %%
# tract the reports (nct id) with the treating purpose
treatment_id_df = d_df[d_df['primary_purpose']=="Treatment"]['nct_id']

# %%
# screen out the treating clinical trial descriptions and conditions
screened_des = pd.merge(df,treatment_id_df,on='nct_id')
screened_cond = pd.merge(screened_des,condi_df, on='nct_id')

# %% [markdown]
# Second cleaning:

# %%
# extract the free text from the file
description = screened_des['description'].values.tolist()

# %%
# cleaning the free text data:
# removing '\r~~', '\r~', '~', etc.

import re;

def clean_description (str):
    # remove '~', 'r~', and 'r~~'
    p = re.compile('\r~~?')
    s = p.sub('', str)
    p = re.compile('~\s+')
    s = p.sub('', s)
    p = re.compile('\s\s+')
    s = p.sub(' ', s)
    p = re.compile('\|')
    s = p.sub('', s)
    p = re.compile('\s-\s|-\s')
    s = p.sub('', s)
    return s

description_cleaned = list(map(clean_description, description))

# %%
# write the cleaned descriptions to file as the input data of CubNER
# screened_des['cleaned_description'] = description_cleaned
# temp = screened_des.sort_values(['nct_id'],ascending=False)
# des_only_ordered = temp['cleaned_description']
# description_file = open("data/treatment_description_only.txt", "w")
# for element in des_only_ordered:
#     description_file.write(element + "\n")
# description_file.close()

# %%
# id extraction
# des_only_nctid_ordered = temp['nct_id']
# des_only_nctid_ordered.to_csv('ids.csv', sep=',',header=True, index=False)

# %% [markdown]
# The following code is for preparing the input data for DNorm.
#
# The input data for DNorm is in PubTator format, since it was built to normalize disease from biomedical article and does text mining from the tiles and the abstracts.
#
# -------------------------------------------------------------------------------------------------------------------
#
# An example of the PubTator input format:
#
# 20085714|t|Autosomal-dominant striatal degeneration is caused by a mutation in the phosphodiesterase 8B gene.
#
# 20085714|a|Autosomal-dominant striatal degeneration (ADSD) is an autosomal-dominant movement disorder affecting the striatal part of the basal ganglia. ADSD is characterized by bradykinesia, dysarthria, and muscle rigidity. These symptoms resemble idiopathic Parkinson disease, but tremor is not present. Using genetic linkage analysis, we have mapped the causative genetic defect to a 3.25 megabase candidate region on chromosome 5q13.3-q14.1. A maximum LOD score of 4.1 (Theta = 0) was obtained at marker D5S1962. Here we show that ADSD is caused by a complex frameshift mutation (c.94G>C+c.95delT) in the phosphodiesterase 8B (PDE8B) gene, which results in a loss of enzymatic phosphodiesterase activity. We found that PDE8B is highly expressed in the brain, especially in the putamen, which is affected by ADSD. PDE8B degrades cyclic AMP, a second messenger implied in dopamine signaling. Dopamine is one of the main neurotransmitters involved in movement control and is deficient in Parkinson disease. We believe that the functional analysis of PDE8B will help to further elucidate the pathomechanism of ADSD as well as contribute to a better understanding of movement disorders.
#
# --------------------------------------------------------------------------------------------------------------------
#
# 't' stands for title, and 'a' stands for 'abstract'. The numbers in the first column are identifiers. The idea here is to have the conditions specified by the clinical trial registers to be the 'title', since these condictions were 'summarized', and have the detialed descriptions of the trial to be the 'abstract'.

# %%
# create a list of "a" representing 'abstract'
alist = ["a"]*len(description_cleaned)

# %%
# append the 'a' and cleaned description to the original dataframe
screened_des['cleaned_description'] = description_cleaned
screened_des['type'] = alist

# drop the id and description columns since they are not useful
ndf = screened_des.drop(['id', 'description'], axis=1)

# %%
# reorder the columns making it consistent with the PubTator input format:
order = [0,2,1] 
ndf = ndf[[ndf.columns[i] for i in order]]

# %%
# I generated a toy dataset to test the format and tried it with DNorm.

short_ndf = ndf.head(10)

# %%
# just filled the title with 'tiltle'
ids = short_ndf['nct_id'].values.tolist()
for id in ids:
    short_ndf = short_ndf.append({'nct_id': id, 'type': 't', 'cleaned_description': 'title'}, ignore_index = True)

# %%
# sorting for haveing rows with the same id be together and 't' on top of 'a'
short_ndf = short_ndf.sort_values(['nct_id', 'type'],ascending=False)

# %%
short_ndf.to_csv('PubTator_short.txt', sep='|',header=False, index=False)

# %%
# the following code is for generatingt the data in PubTator input format
# nctid | type | content

condi_ndf = screened_cond.drop(['id_x','id_y','description','name'], axis=1)

# %%
condi_ndf_dic = condi_ndf.to_dict('records')

# %%
# combining the condistions shared the same nctid with 'and'
# store in a dictionary for easily accessing the content(value) by id(key) later
nctid_names_dict = {}
for d in condi_ndf_dic:
    nid = d['nct_id']
    if nid in nctid_names_dict.keys():
        nctid_names_dict[nid] = nctid_names_dict[nid] + ' and ' + clean_description(d['downcase_name'])
    else:
        nctid_names_dict[nid] = clean_description(d['downcase_name'])

# %%
nctid_names_dict
# Out:
# {'NCT05080569': 'infertility unexplained and luteal phase defect and fertility issues and pregnancy related',
#  'NCT05080543': 'septic shock',
#  'NCT05080530': 'painful diabetic neuropathy',
#  'NCT05077644': 'post-partum depression',
#  'NCT05080322': 'allergic rhinitis',
#  'NCT05080283': 'adult cochlear implant recipients',
#  'NCT05080205': 'insulin resistance and obesity, morbid',
#  'NCT05080114': 'laparoscopy and surgery and hysterectomy',
#  'NCT05080075': 'knee osteoarthritis',
#  'NCT05080010': 'retinoblastoma',
#  'NCT04978467': 'stroke',
#  'NCT05079802': 'resorption of tooth or root',
#  'NCT05079789': 'sodium retention and edema and nephrotic syndrome',
#  'NCT05079646': 'fracture resistance',
#  'NCT05079568': 'gastroparesis',
#  'NCT05079555': 'hip fractures',
#  'NCT05079529': 'cardiometabolic syndrome',
#  'NCT05079503': 'locally advanced rectal cancer',
#  'NCT05079490': 'developmental coordination disorder',
#  'NCT05079464': 'mild cognitive impairment and vascular cognitive impairment',
#  'NCT05079269': 'anesthesia and hypotension drug-induced',
#  'NCT05079256': 'psoriasis vulgaris',
#  'NCT05079243': 'reconstruction and augmentation',
#  'NCT05079087': 'pain, postoperative and pertrochanteric fracture',
#  'NCT05079035': 'knee arthritis and knee pain chronic and knee osteoarthritis',
#  'NCT05079022': 'adenocarcinoma of lung',
#  'NCT05079009': 'pulmonary disease and chronic obstructive pulmonary disease exacerbation and acute respiratory distress syndrome and extracorporeal co2 removal',
#  'NCT05078970': 'suicide threat and suicide and self-harm and suicidal ideation and suicide attempts',
#  'NCT05078944': 'alzheimer disease 1',
#  'NCT05078827': 'actinic keratoses',
#  'NCT05078788': 'urethral stricture',
#  'NCT05078749': 'systemic sclerosis',
#  'NCT05078541': 'radiofrequency ablation',
#  'NCT04705519': 'neuroendocrine carcinoma',
#  'NCT05078736': 'hyperlipidemias',
#  'NCT05078710': 'anti phospholipid syndrome',
#  'NCT05078567': 'plaque psoriasis',
#  'NCT05078489': 'neck pain',
#  'NCT05078463': 'thalassemia in children',
#  'NCT05078398': 'opioid use and breast surgery and breast cancer',
#  'NCT05078385': 'burns',
#  'NCT05078372': 'knee injuries and anesthesia injection site and anterior cruciate ligament injuries',
#  'NCT05078320': 'dysmorphophobia and body dysmorphic disorders',
#  'NCT05078242': 'chronic pain',
#  'NCT05078177': 'multiple sclerosis',
#  'NCT05078099': 'amblyopia',
#  'NCT05078073': 'acute-graft-versus-host disease and hyperbaric oxygen therapy',
#  'NCT05078047': 'melanoma and hepatocellular carcinoma and merkel cell carcinoma and triple negative breast cancer and bladder cancer and head and neck cancer and renal cell carcinoma and lung cancer metastatic',
#  'NCT05077969': 'covid-19 and 2019-ncov infection and 2019-ncov disease and sars-cov-2 acute respiratory disease and sars-cov2 infection and coronavirus disease 2019 and covid19 and covid-19 virus infection and covid-19 virus disease and covid-19 pandemic and 2019 novel coronavirus infection and 2019 novel coronavirus disease',
#  'NCT05077930': 'respiratory tract diseases and coronavirus infections and pneumonia and sars-cov-2 and convalescent plasma and covid-19',
#  'NCT05077813': 'tuberculosis',
#  'NCT05077800': 'pancreatic adenocarcinoma metastatic and pancreatic adenocarcinoma',
#  'NCT05077566': 'low back pain',
#  'NCT05077527': 'recurrent transformed b-cell non-hodgkin lymphoma and refractory transformed b-cell non-hodgkin lymphoma and refractory primary mediastinal (thymic) large b-cell lymphoma and refractory non-hodgkin lymphoma and refractory high grade b-cell lymphoma and refractory grade 3b follicular lymphoma and refractory diffuse large b-cell lymphoma and recurrent primary mediastinal (thymic) large b-cell lymphoma and recurrent non-hodgkin lymphoma and recurrent high grade b-cell lymphoma and recurrent grade 3b follicular lymphoma and recurrent diffuse large b-cell lymphoma and hiv infection and aids-related non-hodgkin lymphoma and aids-related diffuse large b-cell lymphoma',
#  'NCT05077475': 'hypertension',
#  'NCT05077462': 'hypertension',
#  'NCT05077358': 'adenocarcinoma of the colon',
#  'NCT05077332': 'covid-19 and sars-cov-2 acute respiratory disease and sars-cov-2 infection and coronavirus disease 2019 and covid19 and covid-19 virus infection and covid-19 virus disease and covid-19 pandemic and 2019-ncov infection and 2019-ncov disease and 2019 novel coronavirus infection and 2019 novel coronavirus disease',
#  'NCT05077241': 'covid19',
#  'NCT05077098': 'recurrent prostate cancer',
#  'NCT05076994': 'greater trochanteric pain syndrome and low back pain',
#  'NCT05076942': 'lymph node metastases and sentinel lymph node and vulvar cancer',
#  'NCT05076357': 'appetitive behavior and cold exposure and weight loss',
#  'NCT05076760': 'head and neck cancer and triple negative breast cancer and pancreatic cancer and melanoma and merkel cell carcinoma and cutaneous squamous cell carcinoma and non small cell lung cancer and metastatic cancer and advanced cancer and solid tumor',
#  'NCT05076747': 'stroke',
#  'NCT05076695': 'her2-positive breast cancer and estrogen receptor-positive breast cancer',
#  'NCT05076682': 'triple-negative breast cancer',
#  'NCT05076669': 'quality of life and stoma colostomy and stoma ileostomy',
#  'NCT04782765': 'disease-free survival rate',
#  'NCT05076578': 'chronic wound',
#  'NCT05076526': 'osteoarthritis, knee',
#  'NCT05076474': 'bioequivalence',
#  'NCT05076461': 'acute gastroenteritis and vomiting in infants and/or children',
#  'NCT05076253': 'effect of drug and ivermectin poisoning and sars-cov2 infection and safety',
#  'NCT05076123': 'stroke',
#  'NCT05076097': 'mantle cell lymphoma',
#  'NCT05076032': 'infertility and infertility, female',
#  'NCT05076006': 'cicatricial alopecia',
#  'NCT05075993': 'metastatic uveal melanoma and metastatic soft tissue sarcoma and metastatic ovarian carcinoma and metastatic hpv related solid tumors and metastatic hepatocellular carcinoma and metastatic head and neck carcinoma and gastric cancer and metastatic esophageal',
#  'NCT05075863': 'polycystic ovary syndrome',
#  'NCT05075837': 'viral infection after hsct',
#  'NCT05075811': 'fistula and pouch, ileal',
#  'NCT05075681': 'peripheral blood stem cell transplantation',
#  'NCT05066230': 'non-proliferative diabetic retinopathy',
#  'NCT05075668': 'osa',
#  'NCT05075564': 'advanced solid tumor',
#  'NCT05075525': 'orthopedic disorder and physical therapy',
#  'NCT05075512': 'breast neoplasm female',
#  'NCT05075486': 'neonate and mortality and intracranial hemorrhage and quality improvement and extracorporeal membrane oxygenation and extracorporeal life support',
#  'NCT05075473': 'generalized segmental stabilization exercises and segmental stabilization',
#  'NCT05075460': 't-cell lymphoma',
#  'NCT05075447': 'lack of; attention, with hyperactivity (adhd)',
#  'NCT05075434': 'heel pain syndrome and plantar fascitis',
#  'NCT05075395': 'occupational therapy and animal assisted therapy and physical therapy modalities and critical illness and pediatric all',
#  'NCT05075161': 'acute respiratory distress syndrome (ards)',
#  'NCT05075122': 'head and neck squamous cell carcinoma',
#  'NCT05075109': 'stroke',
#  'NCT05075005': 'plantar fasciitis',
#  'NCT05074992': 'glioblastoma',
#  'NCT05074940': 'salivary gland cancer',
#  'NCT05074914': 'oesophageal cancer',
#  'NCT05070689': 'placenta accreta',
#  'NCT05074784': 'dysphagia',
#  'NCT05074693': 'depression symptoms and anxiety sensitivity',
#  'NCT05074641': 'neck pain',
#  'NCT05074628': 'intracanal medication',
#  'NCT05074615': 'neck pain',
#  'NCT05074576': 'physical therapy and manual therapy and orthopedic disorder of spine',
#  'NCT05074524': 'transcranial magnetic stimulation and craving and heroin abuse and opioid-use disorder',
#  'NCT05074472': 'ovarian serous cystadenocarcinoma and biliary cancer metastatic and ovarian serous adenocarcinoma and pancreatic ductal; adenocarcinoma and solid tumor, adult',
#  'NCT05074394': 'covid-19',
#  'NCT05074381': 'mobility limitation and headache and neck pain, posterior',
#  'NCT05074355': 'bcr-abl negative and myeloproliferative neoplasm',
#  'NCT05074329': 'chronic hip pain and idiopathic hip pain',
#  'NCT05071300': 'hereditary transthyretin-mediated amyloid polyneuropathy',
#  'NCT05026528': 'type 2 diabetes',
#  'NCT05074147': 'osteomyelitisfoot',
#  'NCT05025930': 'urologic neoplasms',
#  'NCT05074030': 'alcohol use disorder',
#  'NCT05073575': 'periodontal bone loss',
#  'NCT05073081': 'prehabilitation and lumbar spinal stenosis',
#  'NCT05073744': 'safety and ablation and nalbuphine allergy',
#  'NCT05073731': 'multiple sclerosis',
#  'NCT05073679': 'anorexia in adolescence and anorexia nervosa/bulimia and eating disorders in adolescence and bulimia nervosa and eating disorders and impulsive behavior and purging (eating disorders) and anorexia nervosa, binge eating/purging type and anorexia nervosa, atypical',
#  'NCT05073640': 'schizophrenia',
#  'NCT05073471': 'upper extremity dysfunction and corticobasal syndrome',
#  'NCT05073458': 'warm autoimmune hemolytic anemia (waiha)',
#  'NCT05073380': 'child development',
#  'NCT05073302': 'type 1 diabetes',
#  'NCT05073276': 'knee injuries',
#  'NCT05073263': 'knee injuries',
#  'NCT05073250': "inert non hodgkin's lymphoma",
#  'NCT05070650': 'common cold',
#  'NCT05073237': 'obesity and prediabetes and menopause',
#  'NCT05073133': 'muscular atrophy, spinal',
#  'NCT05073055': 'peripheral nerve blocks and postoperative pain and inguinal hernia repair',
#  'NCT05072938': 'gastritis',
#  'NCT05072899': 'chronic shoulder pain',
#  'NCT05072782': 'crohn disease',
#  'NCT05072730': 'calcified coronary artery disease (grade 3)',
#  'NCT05072704': 'primary total hip arthroplasty',
#  'NCT04922138': 'lung cancer',
#  'NCT05072600': 'neoplasms, bladder and urinary bladder cancer and bladder tumors and bladder neoplasms and bladder cancer',
#  'NCT05072548': 'behavioural insomnia of childhood and sleep problems',
#  'NCT05072522': 'advanced solid tumors',
#  'NCT05072353': 'amputation and diabetic foot ulcer and diabetic foot',
#  'NCT05072327': 'eyelid tumor',
#  'NCT05072106': 'advanced solid tumor',
#  'NCT05072028': 'healthy male subjects',
#  'NCT05071989': 'adolescent behavior',
#  'NCT05071950': 'glucose, high blood',
#  'NCT05071937': 'fallopian tube cancer and peritoneal cancer and ovarian cancer',
#  'NCT05055349': 'keratoconus',
#  'NCT05071885': 'stroke, spinal cord injury',
#  'NCT05071664': 'arthritis, psoriatic',
#  'NCT05071638': 'bpd',
#  'NCT05071547': 'chronic pain',
#  'NCT04993690': 'b-cell lymphoma',
#  'NCT05071469': 'weakness, muscle and musculoskeletal pain and musculoskeletal injury and musculoskeletal diseases and subacromial impingement syndrome',
#  'NCT05071443': 'necrotising soft tissue infections',
#  'NCT05071430': 'panic disorder',
#  'NCT05071417': 'atheroscleroses, coronary',
#  'NCT05071365': 'plantar fascitis',
#  'NCT05071352': 'sedation and mechanical ventilation and critical illness and analgesia',
#  'NCT05071339': 'ivf',
#  'NCT05069922': 'burns',
#  'NCT05071274': 'acne vulgaris',
#  'NCT05071235': 'diabetic foot and diabetic foot ulcer',
#  'NCT05071209': 'recurrent malignant solid neoplasm and refractory malignant solid neoplasm and refractory lymphoma and refractory ewing sarcoma and refractory alveolar rhabdomyosarcoma and recurrent lymphoma and recurrent ewing sarcoma and recurrent alveolar rhabdomyosarcoma',
#  'NCT04993664': 'genetic polymorphisms and inflammation and lipoproteinemia and acute coronary syndrome',
#  'NCT05071183': 'advanced solid tumor and metastatic solid tumor and kras mutation-related tumors',
#  'NCT05071105': 'breast neoplasm female',
#  'NCT05071053': 'gastrooesophageal cancer and adenocarcinoma gastric',
#  'NCT05070936': 'individuals between the ages of 18-65 and individuals with vestibular hypofunction',
#  'NCT05070832': 'radiotherapy and hyperthermia',
#  'NCT05070793': 'alcohol use disorder',
#  'NCT05070728': 'uveitis, intermediate and uveitis, posterior and uveitis',
#  'NCT05070637': 'circulating tumor cell and renal cell carcinoma',
#  'NCT05070611': 'chalazion',
#  'NCT05070520': 'malaria',
#  'NCT05070468': 'pregnancy and dexamethasone',
#  'NCT05070364': 'hepatitis delta virus',
#  'NCT05070260': 'acute ischemic stroke',
#  'NCT05070247': 'gastric adenocarcinoma and esophageal adenocarcinoma and gastroesophageal junction adenocarcinoma and triple negative breast cancer and non-squamous non-small-cell lung cancer and mesothelioma and squamous cell carcinoma and hepatocellular carcinoma and pancreatic adenocarcinoma',
#  'NCT05070221': 'melanoma stage iv',
#  'NCT05070195': 'healthy subjects',
#  'NCT05070052': 'clinical high risk and parents and bipolar disorder and prodromal symptoms and mood disorders',
#  'NCT05070013': "sleep fragmentation and parkinson's disease",
#  'NCT05069987': 'anxiety and aortic stenosis, severe',
#  'NCT05069961': 'rib fractures',
#  'NCT05069948': 'concussion, mild',
#  'NCT05069935': 'solid tumor, adult',
#  'NCT05032859': 'atopic dermatitis',
#  'NCT05069870': 'healthy subjects',
#  'NCT05069857': 'anti-vegfr and anti-pd-1 and neoadjvant therapy and oral squamous cell carcinoma',
#  'NCT05032846': 'benign ovarian cyst',
#  'NCT05069766': 'esophagus cancer, adenocarcinoma',
#  'NCT05069727': 'diabetes type1',
#  'NCT05069688': 'tuberculosis infection and pediatric hiv infection',
#  'NCT05069610': 'covid19',
#  'NCT05069480': 'upper extremity dysfunction and spastic hemiplegia and spasticity as sequela of stroke',
#  'NCT05069428': 'delirium',
#  'NCT05069402': 'complication,postoperative',
#  'NCT05007145': 'esophageal squamous cell carcinoma and esophageal neoplasms',
#  'NCT05069285': 'hypnotic; sleep disorder',
#  'NCT05069246': 'gingivitis',
#  'NCT04999501': 'resistance training and aged, 80 and over',
#  'NCT05068947': 'safety issues',
#  'NCT05069051': 'chronic lymphoid leukemia in relapse',
#  'NCT05069012': 'postoperative pain',
#  'NCT05068960': 'total shoulder arthroplasty',
#  'NCT05068050': 'arthritis',
#  'NCT05068882': 'postoperative complications',
#  'NCT05068739': 'pancreatic disease and malignant hepatobiliary neoplasm and biliary stricture and common bile duct calculi and biliary disease',
#  'NCT05068700': 'anaesthesia and nursing and conscious sedation',
#  'NCT05068674': 'chronic ischemic left ventricular dysfunction',
#  'NCT05068661': 'labor pain',
#  'NCT05066217': 'lennox gastaut syndrome',
#  'NCT05068570': 'effect of arm ergometry on respiration',
#  'NCT05068557': 'chronic inflammation and obesity',
#  'NCT05068479': 'presbyopia',
#  'NCT05068453': 'melanoma stage iv',
#  'NCT05068427': 'non small cell lung cancer',
#  'NCT05068362': 'microtia',
#  'NCT05068349': 'vascular diseases and central nervous system diseases and nervous system diseases and brain ischemia and brain infarction and cerebral infarction and stroke',
#  'NCT05068024': 'carcinoma, non-small-cell lung',
#  'NCT05068245': 'anxiety and pain, acute',
#  'NCT05068219': 'surgery, cardiac',
#  'NCT05068141': 'triple negative breast cancer',
#  'NCT04998604': 'asthma and chronic rhinosinusitis with nasal polyps',
#  'NCT05067894': 'covid19',
#  'NCT05067855': 'sports physical therapy',
#  'NCT05067218': 'vibration and anesthesia, local and anesthesia',
#  'NCT05067829': 'rocuronium and rapid sequence intubation and rapid sequence induction',
#  'NCT05067777': 'prostate carcinoma',
#  'NCT05066997': 'diabetic macular edema',
#  'NCT05067712': 'embedded and impacted teeth',
#  'NCT05067673': 'low back pain',
#  'NCT05067660': 'prostate cancer recurrence after radical prostatectomy',
#  'NCT05067634': 'partial epilepsy',
#  'NCT05067621': 'obesity, childhood and non-alcoholic fatty liver disease and impaired glucose tolerance and type 2 diabetes mellitus',
#  'NCT05067608': 'hypoproliferative thrombocytopenia',
#  'NCT05067595': 'intestinal graft versus host disease',
#  'NCT05067569': 'insomnia',
#  'NCT05067517': 'progressive fibrosing interstitial lung disease',
#  'NCT05067491': 'specific phobia, animal',
#  'NCT05067465': 'healthy lifestyle',
#  'NCT05066646': 'multiple myeloma',
#  'NCT05067426': 'performance and athlete and healthy',
#  'NCT05067413': 'rectal neoplasms malignant',
#  'NCT05067348': 'myasthenia gravis, generalized',
#  'NCT05067257': 'pain and pain cancer and pain, intractable',
#  'NCT05067205': 'carpal tunnel syndrome',
#  'NCT05067140': 'prostate cancer metastatic',
#  'NCT05067101': 'bladder cancer',
#  'NCT05066984': 'post icu syndrome',
#  'NCT05066893': 'children, only and type 1 diabetes',
#  'NCT05066841': 'childhood asthma',
#  'NCT05066802': 'resectable pancreatic adenocarcinoma',
#  'NCT05066789': 'coronary artery disease',
#  'NCT05066737': 'pelvic organ prolapse',
#  'NCT05066724': 'smoking cessation',
#  'NCT05066672': 'treatment resistant depression',
#  'NCT05066633': 'muscular dystrophy, duchenne',
#  'NCT05066620': 'intracerebral hemorrhage',
#  'NCT05066607': 'al amyloidosis',
#  'NCT04882241': 'gastroesophageal junction cancer and gastric cancer',
#  'NCT05066490': 'vitamin d deficiency and obesity',
#  'NCT04882228': 'chronic venous disease',
#  'NCT05066451': 'lateral epicondylitis',
#  'NCT05066412': 'haplo-identical stem cell transplantation and hematologic malignancy',
#  'NCT05066334': 'chronic low-back pain and intervertebral disc degeneration',
#  'NCT05066321': 'serious bacterial infections and opioid-use disorder',
#  'NCT05066178': 'autism spectrum disorder and developmental verbal dyspraxia',
#  'NCT05066100': 'retracted nipple and inverted nipple',
#  'NCT05066087': 'chronic pain',
#  'NCT05066074': 'coronary artery disease',
#  'NCT05066035': 'rocuronium and postoperative residual curarization and complication of anesthesia and neostigmine and sugammadex and neuromuscular blockade',
#  'NCT05065957': 'biliary tract cancer',
#  'NCT05065905': 'rna virus infections and lentivirus infections and human immunodeficiency virus and tuberculosis, pulmonary and aids/hiv problem and hiv coinfection',
#  'NCT05065801': 'metastatic pancreatic cancer',
#  'NCT05065554': 'neuropathy;peripheral and waldenstrom macroglobulinemia and igm mgus',
#  'NCT05065359': 'healthy',
#  'NCT05065411': 'metastatic breast cancer',
#  'NCT05065346': 'head and neck squamous cell carcinoma and squamous cell carcinoma',
#  'NCT04627428': 'dry age-related macular degeneration',
#  'NCT05065164': 'denosumab and screw internal fixation of osteoporotic vertebral compression fracture',
#  'NCT05065138': 'helicobacter pylori infection',
#  'NCT05065047': 'multiple myeloma',
#  'NCT05065021': 'high grade endometrioid cancer and high grade serous cancer and primary peritoneal cancer and fallopian tube cancer and ovarian cancer',
#  'NCT04627415': 'parenting and child behavior and parent-child relations and attention deficit hyperactivity disorder',
#  'NCT05064930': 'irritable bowel syndrome',
#  'NCT04838808': 'type ii myocardial infarction',
#  'NCT05064761': 'cellulite',
#  'NCT05064748': 'psoriasis',
#  'NCT05064709': 'heart failure with mid range ejection fraction and heart failure with preserved ejection fraction and heart failure',
#  'NCT05064618': 'pancreatic cancer',
#  'NCT05064514': 'carcinoid heart disease and carcinoid syndrome and tricuspid valve disease and tricuspid regurgitation',
#  'NCT05064345': 'healthy',
#  'NCT05064293': 'mental health issue and adolescent behavior',
#  'NCT05064280': 'tumor and brain metastases',
#  'NCT05064228': 'alcohol use disorder (aud)',
#  'NCT05064202': 'acute decompensated heart failure',
#  'NCT05064176': 'lymphedema and lymphedema arm and lymphoedema of leg',
#  'NCT05064033': 'shoulder pain chronic and shoulder bursitis and shoulder capsulitis and shoulder injuries and shoulder arthritis and shoulder impingement',
#  'NCT05063994': 'congenital adrenal hyperplasia',
#  'NCT05063968': 'non-alcoholic fatty liver disease',
#  'NCT05063916': 'cervical cancer and cervix cancer and carcinomas',
#  'NCT05063877': 'epilepsy',
#  'NCT05063799': 'pregnancy and pulmonary rehabilitation and covid-19 pneumonia',
#  'NCT05063786': 'advanced breast cancer',
#  'NCT05063721': 'mitochondrial myopathies',
#  'NCT05063708': 'multiple sclerosis and deglutition disorders',
#  'NCT05063682': 'glioma, malignant and glioblastoma multiforme and glioblastoma',
#  'NCT05063552': 'stage ivc sinonasal cancer ajcc v8 and stage ivc oropharyngeal (p16-negative) carcinoma ajcc v8 and stage ivc lip and oral cavity cancer ajcc v8 and stage ivc laryngeal cancer ajcc v8 and stage ivc hypopharyngeal carcinoma ajcc v8 and stage ivb sinonasal cancer ajcc v8 and stage ivb oropharyngeal (p16-negative) carcinoma ajcc v8 and stage ivb nasopharyngeal carcinoma ajcc v8 and stage ivb lip and oral cavity cancer ajcc v8 and stage ivb laryngeal cancer ajcc v8 and stage ivb hypopharyngeal carcinoma ajcc v8 and stage iva sinonasal cancer ajcc v8 and stage iva oropharyngeal (p16-negative) carcinoma ajcc v8 and stage iva nasopharyngeal carcinoma ajcc v8 and stage iva lip and oral cavity cancer ajcc v8 and stage iva laryngeal cancer ajcc v8 and stage iva hypopharyngeal carcinoma ajcc v8 and stage iv sinonasal cancer ajcc v8 and stage iv oropharyngeal (p16-negative) carcinoma ajcc v8 and stage iv nasopharyngeal carcinoma ajcc v8 and stage iv lip and oral cavity cancer ajcc v8 and stage iv laryngeal cancer ajcc v8 and stage iv hypopharyngeal carcinoma ajcc v8 and recurrent sinonasal squamous cell carcinoma and recurrent pharyngeal squamous cell carcinoma and recurrent nasopharyngeal squamous cell carcinoma and recurrent lip and oral cavity squamous cell carcinoma and recurrent laryngeal squamous cell carcinoma and recurrent hypopharyngeal squamous cell carcinoma and recurrent head and neck squamous cell carcinoma and pathologic stage iv hpv-mediated (p16-positive) oropharyngeal carcinoma ajcc v8 and metastatic sinonasal squamous cell carcinoma and metastatic pharyngeal squamous cell carcinoma and metastatic nasopharyngeal squamous cell carcinoma and metastatic nasal cavity squamous cell carcinoma and metastatic lip and oral cavity carcinoma and metastatic laryngeal squamous cell carcinoma and metastatic hypopharyngeal squamous cell carcinoma and metastatic head and neck squamous cell carcinoma and clinical stage iv hpv-mediated (p16-positive) oropharyngeal carcinoma ajcc v8 and clinical stage i hpv-mediated (p16-positive) oropharyngeal carcinoma ajcc v8',
#  'NCT05063669': 'cognitive deficit and adhd',
#  'NCT05063656': 'autism spectrum disorder',
#  'NCT05063513': 'refractory systemic lupus erythematosus',
#  'NCT05063500': 'drug-induced acute liver injury',
#  'NCT05063409': 'burn injury',
#  'NCT05063396': 'thoracic cancer',
#  'NCT05063357': 'dipg',
#  'NCT05063318': 'advanced solid tumors',
#  'NCT05063253': 'type 2 diabetes mellitus',
#  'NCT05063175': 'kyphosis',
#  'NCT05063110': 'adults patients having non severe hlh',
#  'NCT05063071': 'post liver transplant and hbv',
#  'NCT05062980': 'non small cell lung cancer',
#  'NCT05062941': 'chronic shoulder pain',
#  'NCT05062902': 'pelvic floor disorders and pelvic floor; relaxation and chronic pain and interstitial cystitis',
#  'NCT05062889': 'stage iii colon cancer and stage ii colon cancer',
#  'NCT05062837': 'hepatocellular carcinoma',
#  'NCT04864054': 'metastatic liver cancer and liver neoplasm and liver cancer, adult and hepatocellular carcinoma',
#  'NCT05062785': 'healthy and out-of-hospital cardiac arrest',
#  'NCT05062720': 'colorectal cancer metastatic',
#  'NCT05062577': 'opioid use disorder',
#  'NCT05062551': 'abnormal uterine bleeding',
#  'NCT05062486': 'age-related macular degeneration',
#  'NCT05062369': 'addiction and alcohol use disorder',
#  'NCT05062356': 'chronic postoperative pain',
#  'NCT05062343': 'induced; birth',
#  'NCT05062317': 'liver metastases',
#  'NCT05062070': 'epidermolysis bullosa simplex',
#  'NCT05061914': 'pericardial effusion',
#  'NCT05061836': 'pediatric surgery',
#  'NCT05061758': 'sensorineural hearing loss',
#  'NCT05061719': 'major depressive disorder',
#  'NCT05061706': 'major depressive disorder',
#  'NCT05061667': 'postoperative pain',
#  'NCT05003752': 'radiation toxicity and prostate adenocarcinoma',
#  'NCT05061654': 'hematologic cancer and neutropenia, febrile',
#  'NCT05061641': 'preterm birth',
#  'NCT05061550': 'non-small cell lung cancer',
#  'NCT05061524': 'adult subjects with mild allergic diseases and atopic healthy subjects',
#  'NCT05061381': 'low mood and anxiety',
#  'NCT05061368': 'chronic obstructive pulmonary disease',
#  'NCT05061355': 'endocarditis infective',
#  'NCT05003726': 'radiculopathy lumbar and lumbar disc herniation',
#  'NCT05061316': 'nutrition aspect of cancer and cancer of head and neck',
#  'NCT05061264': 'infection and abdominal wall fistula and abdominal wall infection and abdominal wall hernia and abdominal wall defect',
#  'NCT05061251': 'idh mutation and glioma',
#  'NCT05061225': 'anxiety disorders and symptoms and depressive symptoms and stress, psychological and ptsd',
#  'NCT05061147': 'myelodysplastic syndrome and relapsed/refractory acute myeloid leukemia and acute myeloid leukemia and leukemia',
#  'NCT05061121': 'neck pain',
#  'NCT05061043': 'stroke',
#  'NCT05061017': 'refractory melanoma and metastatic colorectal carcinoma and nsclc',
#  'NCT05060809': 'vascular calcification',
#  'NCT05060796': 'non small cell lung cancer',
#  'NCT05060744': 'hyperactivity; stomach and gastric reflux and oesophageal reflux',
#  'NCT05060731': 'anemia and gastrointestinal bleeding',
#  'NCT05060653': 'surgery and radiosurgery and neoplasm metastasis and spinal neoplasms',
#  'NCT05060601': 'periodontal inflammation and periodontal diseases',
#  'NCT05060536': 'arthroplasty complications and knee discomfort',
#  'NCT05060523': 'liver cirrhosis',
#  'NCT05060432': 'melanoma and head and neck cancer and lung cancer and advanced cancer',
#  'NCT05060406': 'postmenopausal osteoporosis',
#  'NCT05060393': 'depression',
#  'NCT05060276': 'relapsed solid neoplasm and solid tumor, adult and refractory cancer',
#  'NCT05060224': 'quality of life',
#  'NCT05060198': 'malaria,falciparum',
#  'NCT05060159': 'cognitive impairment and cerebral edema and hemodialysis complication and dialysis; complications',
#  'NCT05060081': 'sports physical therapy',
#  'NCT05060068': 'breast cancer surgery',
#  'NCT05060055': 'dental implant failed',
#  'NCT05059938': 'weight reduction',
#  'NCT05059847': 'acute lymphoblastic leukemia, adult b-cell',
#  'NCT05059821': 'hepatocellular carcinoma',
#  'NCT04935502': 'musculoskeletal pain',
#  'NCT05059782': 'cancer of the ovary and cancer of ovary and ovarian cancers and cancers, ovarian and cancer, ovarian and ovary cancers and cancers, ovary and cancer, ovarian stromal and ovary cancer and neoplasms, ovarian and ovary neoplasm and neoplasms, ovary and neoplasm, ovary and ovary neoplasms and ovarian neoplasm and neoplasm, ovarian and ovarian cancer',
#  'NCT05059756': 'pelvic floor disorders and childhood all and constipation',
#  'NCT05059704': 'stroke',
#  'NCT05059522': 'solid tumors and urothelial cancer and ovarian cancer and nsclc and advanced malignancies',
#  'NCT05059496': 'low back pain',
#  'NCT05059470': 'thyroid',
#  'NCT05059418': 'burning mouth syndrome',
#  'NCT04935489': 'treatment resistant depression',
#  'NCT05059353': 'mild cognitive impairment',
#  'NCT05059327': 'tuberous sclerosis complex',
#  'NCT05059275': 'tarlov cysts',
#  'NCT05059223': 'excessive daytime sleepiness and cataplexy and narcolepsy',
#  'NCT05059145': 'candidiasis, vulvovaginal',
#  'NCT05059054': 'fasciitis, plantar, chronic and plantar fascitis',
#  'NCT05058976': 'osteoporosis fracture and osteoporosis, postmenopausal and osteoporosis',
#  'NCT05058963': 'substance use disorders and post traumatic stress disorder',
#  'NCT05057884': 'heart failure',
#  'NCT05058859': 'cystinuria',
#  'NCT05058755': 'natural killer/t-cell lymphoma, nasal and nasal-type',
#  'NCT05057871': 'shoulder injuries and disorders and subacromial impingement syndrome and musculoskeletal diseases and shoulder pain',
#  'NCT04621136': 'retinopathy of prematurity',
#  'NCT05058625': 'sports physical therapy',
#  'NCT05058612': 'vasoplegia',
#  'NCT05058586': 'stroke, cardiovascular',
#  'NCT04621123': 'safety and efficacy and sars-cov-2 infection',
#  'NCT04621097': 'peripheral arterial disease',
#  'NCT05058573': 'tension-type headache',
#  'NCT05058560': 'nsclc',
#  'NCT05058482': 'intracranial arteriovenous malformations',
#  'NCT05058443': 'denosumab and percutaneous kyphoplasty',
#  'NCT05058404': 'follicular lymphoma',
#  'NCT05058287': 'pain, back and pain, postoperative and lumbar spinal stenosis and opioid use',
#  'NCT05058235': 'knee osteoarthritis',
#  'NCT05058222': 'coronary artery bypass graft',
#  'NCT05058209': 'osteoarthritis, knee',
#  'NCT05058066': 'hearing loss',
#  'NCT05058040': 'alzheimer disease',
#  'NCT05055154': 'dna damage and weight loss and obesity',
#  'NCT05057988': 'pain and chronic pain and opioid-use disorder',
#  'NCT05057845': 'advanced hepatocellular carcinoma',
#  'NCT05057793': 'venous ulcer and leg ulcer and venous leg ulcer',
#  'NCT05054946': 'ovarian cysts',
#  'NCT05057715': 'serous ovarian cancer and pancreatic cancer',
#  'NCT05057689': 'pain and anxiety and acute stress disorder',
#  'NCT05057624': 'posttraumatic stress disorder',
#  'NCT05057611': 'septic shock',
#  'NCT05057494': 'chronic lymphocytic leukemia or small lymphocytic lymphoma',
#  'NCT05057364': 'heart failure',
#  'NCT05057338': 'multiple sclerosis',
#  'NCT04777266': 'schizophrenia; psychosis',
#  'NCT05057247': 'advanced head and neck squamous cell carcinoma and advanced head and neck cancer and metastatic head and neck cancer and recurrent squamous cell carcinoma of the head and neck and squamous cell carcinoma of the head and neck (scchn)',
#  'NCT05057195': 'soft tissue sarcoma and sarcoma',
#  'NCT05057143': 'implant site reaction and surgery and sarcoma of bone and chest wall sarcoma and chest wall tumor and tumor of bone',
#  'NCT05057130': 'sarcoma of bone and sarcoma and neoplasms, connective and soft tissue and neoplasms, connective tissue and osteosarcoma',
#  'NCT05057091': 'chronic low-back pain',
#  'NCT05057052': 'colorectal cancer metastatic and liver metastases',
#  'NCT05057000': 'anorexia in adolescence',
#  'NCT05056987': 'refractive errors',
#  'NCT05054426': 'central nervous system lymphoma and diffuse large b cell lymphoma',
#  'NCT05056909': 'chronic kidney diseases',
#  'NCT05056753': 'opioid-use disorder',
#  'NCT05056675': 'pain, postoperative',
#  'NCT05056506': 'choledocholithiasis',
#  'NCT04508660': 'rosacea',
#  'NCT05056389': 'colo-rectal cancer and peritoneal metastases',
#  'NCT05056337': 'hepatocellular carcinoma',
#  'NCT05056298': 'muscle weakness and balance; distorted and flexible flatfoot and flat feet',
#  'NCT05055765': 'thin gingiva',
#  'NCT05056233': 'cataract and dry eye disease',
#  'NCT05056155': 'dry eye disease',
#  'NCT05056116': 'biliary tract cancer',
#  'NCT05055726': 'head and neck cancer and radiation-induced mucositis',
#  'NCT05055687': 'healthy',
#  'NCT05055674': 'postpartum depression',
#  'NCT05055648': 'proton therapy and side effect and radiotherapy and esophageal cancer',
#  'NCT05055609': 'oncology and solid tumor, adult',
#  'NCT05055596': 'chronic pain and hiv infections',
#  'NCT05055583': 'oligometastasis and nsclc stage iv',
#  'NCT04922450': 'squamous cell carcinoma and head and neck cancer',
#  'NCT05055544': 'cystitis',
#  'NCT05055518': 'advanced solid tumor',
#  'NCT05055427': 'herbal medicine and covid-19 respiratory infection',
#  'NCT05055414': 'coronavirus infection',
#  'NCT05055284': 'anterior knee pain syndrome and patellofemoral disorder',
#  'NCT05055232': 'alk rearrangement non-small cell lung cancer and ros1 rearrangement non-small cell lung cancer',
#  'NCT05055115': 'middle ear problem and hearing loss, conductive and middle ear disease and eustachian tube dysfunction',
#  'NCT05055063': 'myeloma',
#  'NCT05055050': 'bladder and bladder cancer',
#  'NCT05054985': 'thoracoabdominal aortic aneurysms',
#  'NCT05054959': 'locally advanced rectal cancer',
#  'NCT05054894': 'age-related frailty',
#  'NCT05054868': 'arthrodesis',
#  'NCT05054803': 'spinal cord injury cervical',
#  'NCT05054738': 'dual diagnosis and substance-related disorders and alcoholism',
#  'NCT05054725': 'non-small cell lung cancer',
#  'NCT05054699': 'bipolar depression and major depressive disorder',
#  'NCT05054686': 'knee osteoarthritis',
#  'NCT05051865': 'melanoma',
#  'NCT04897321': 'soft tissue sarcoma and malignant peripheral nerve sheath tumors and carcinoma and melanoma and hepatoblastoma and clear cell sarcoma and rhabdoid tumor and germ cell cancer and desmoplastic small round cell tumor and adrenocortical cancer and wilms tumor and ewing sarcoma and neuroblastoma and rhabdomyosarcoma and osteosarcoma and pediatric solid tumor',
#  'NCT05054543': 'relapsed/refractory aml',
#  'NCT05054465': 'acute lymphoblastic leukemia',
#  'NCT05054400': 'glioblastoma and gliomas and cancer and brain metastases',
#  'NCT05054322': 'covid19',
#  'NCT05054257': "non-hodgkin's lymphoma, relapsed and non-hodgkin's lymphoma refractory and relapsed or refractory b-cell acute lymphoblastic leukemia",
#  'NCT05048056': 'atopic dermatitis',
#  'NCT05048043': 'attention deficit hyperactivity disorder',
#  'NCT04729400': 'epicondylitis',
#  'NCT05054075': 'covid-19 and sars (severe acute respiratory syndrome) and coronavirus sars-associated and coronavirus infections',
#  'NCT05054023': 'acute pain',
#  'NCT05022745': 'instable spine and opioid use and mobility',
#  'NCT05053997': 'lung cancer',
#  'NCT05053971': 'stage ii pancreatic cancer ajcc v8 and refractory t-cell non-hodgkin lymphoma and refractory pancreatic carcinoma and refractory malignant solid neoplasm and refractory lymphoma and refractory b-cell non-hodgkin lymphoma and metastatic pancreatic carcinoma and b-cell non-hodgkin lymphoma and advanced pancreatic carcinoma and advanced malignant solid neoplasm and advanced lymphoma and unresectable pancreatic carcinoma and stage iv pancreatic cancer ajcc v8 and stage iii pancreatic cancer ajcc v8',
#  'NCT05053919': 'insomnia',
#  'NCT05053854': 'neuroendocrine tumors',
#  'NCT05053763': 'anesthesia',
#  'NCT05053750': 'primary peritoneal cancer and fallopian tube and epithelial ovarian',
#  'NCT05053724': 'mechanical ventilation complication and intensive care unit syndrome and intensive care neuropathy and intensive care unit delirium and intensive care unit acquired weakness',
#  'NCT05052528': 'refractory diffuse large b-cell lymphoma and recurrent diffuse large b-cell lymphoma',
#  'NCT05053672': 'low back pain',
#  'NCT05053659': 'refractory non-hodgkin lymphoma and relapsed non hodgkin lymphoma',
#  'NCT05053646': 'meniscal tear',
#  'NCT05053594': 'neuromuscular block prolonged and neuromuscular block, residual and neuromuscular blockade',
#  'NCT05053555': 'melanoma and pancreatic cancer and cholangiocarcinoma metastatic and liver malignant tumors',
#  'NCT05053529': 'stroke',
#  'NCT05053477': 'carpal tunnel syndrome',
#  'NCT05053373': 'stress urinary incontinence in women',
#  'NCT05053438': 'avoidant/restrictive food intake disorder and feeding and eating disorders and feeding disorders',
#  'NCT05053425': 'acute myeloid leukemia',
#  'NCT05053386': 'hepatocellular carcinoma',
#  'NCT05052515': 'nafld',
#  'NCT05053321': 'tardive dyskinesia',
#  'NCT05053308': 'breakthrough pain and cancer pain',
#  'NCT05053165': 'non-alcoholic steatohepatitis and rheumatoid arthritis',
#  'NCT05052255': 'advanced solid tumor',
#  'NCT05053152': 'stage ivb prostate cancer ajcc v8 and prostate adenocarcinoma and oligometastatic prostate carcinoma',
#  'NCT05053035': 'amyotrophic lateral sclerosis',
#  'NCT05053022': 'vitiligo',
#  'NCT05052970': 'relapsed or refractory multiple myeloma',
#  'NCT05052918': 'atherosclerosis and metformin and exercise and pre diabetes',
#  'NCT05052840': 'muscle stretching exercises and paraspinal muscles and mechanical low back pain',
#  'NCT05052814': 'endodontically treated teeth',
#  'NCT05052762': 'sacroiliac disorder',
#  'NCT05052749': 'post menopause',
#  'NCT05052593': 'osteoarthritis, knee',
#  'NCT05052567': 'pancreatic cancer',
#  'NCT05052554': "descemet's membrane disorder and lrs and corneal diseases and fecd3 and fuchs endothelial corneal dystrophy",
#  'NCT05052541': 'neck pain and back pain',
#  'NCT05052398': 'chemotherapy-induced peripheral neuropathy',
#  'NCT04674722': 'radiotoxicity and breast cancer',
#  'NCT05052281': 'prenatal stress',
#  'NCT05052268': 'advanced solid tumor',
#  'NCT05052151': 'end stage renal disease on dialysis',
#  'NCT05052125': 'chronic obstructive pulmonary disease',
#  'NCT05051787': 'breast feeding, exclusive',
#  'NCT05051748': 'dental fluorosis',
#  'NCT05051696': 'genital neoplasms, female',
#  'NCT05051683': 'abdomen, acute',
#  'NCT05051670': 'gastric cancer',
#  'NCT05051475': 'barrett esophagus and reflux disease and esophageal adenocarcinoma',
#  'NCT05051410': 'postoperative pain',
#  'NCT05051397': 'carbon dioxide and cerebrovascular circulation and anesthesia, general and thrombectomy and ischemic stroke, acute',
#  'NCT05051332': 'articular cartilage degeneration and articular cartilage defect',
#  'NCT05051280': 'cardiovascular diseases',
#  'NCT05051163': 'malnutrition, child and hiv-1-infection',
#  'NCT05051085': 'pathological gambling',
#  'NCT05050994': 'portal hypertension and panhematopenia; splenic and splenomegaly; congestive, chronic',
#  'NCT05050929': 'brain metastases, adult',
#  'NCT05050630': "the researchers judged that life expectancy was at least three months and ecog physical status score is 0-3 and at least one positive lesion according to the 2014 lugano criteria for hodgkin's and non-hodgkin's lymphoma and received prior first-line chemotherapy for dlbcl or hgbl, failed to reach cr for four cycles, or relapsed and histopathology confirmed diffuse large b-cell lymphoma or high-grade b-cell lymphoma and age range ≥16 years, gender unlimited and understand and voluntarily sign written informed consent",
#  'NCT05050604': 'vascular cognitive impairment',
#  'NCT05050591': 'pulmonary disease, chronic obstructive',
#  'NCT05050578': 'refractive errors',
#  'NCT05050396': 'osteoarthritis, knee',
#  'NCT05050357': 'pelvic congestion',
#  'NCT05050305': 'multiple myeloma, refractory and multiple myeloma in relapse and multiple myeloma',
#  'NCT05050292': 'insomnia type; sleep disorder and insomnia',
#  'NCT05050253': 'peritonitis',
#  'NCT05003700': 'hepatocellular carcinoma',
#  'NCT05050201': 'first episode psychosis and psychosis and insomnia',
#  'NCT05050188': 'erosive esophagitis',
#  'NCT05050162': 'squamous cell carcinoma of unknown primary and advanced oropharyngeal squamous cell carcinoma and advanced laryngeal squamous cell carcinoma and advanced hypopharyngeal squamous cell carcinoma and advanced head and neck squamous cell carcinoma',
#  'NCT05050084': 'prostate adenocarcinoma',
#  'NCT05049525': "inflammatory bowel diseases and crohn's disease",
#  'NCT05049512': 'allergy, nut',
#  'NCT05050071': 'drug effect',
#  'NCT05049954': 'weight loss and metabolic syndrome and obesity and ketogenic dieting',
#  'NCT05049928': 'obstructive sleep apnea syndrome',
#  'NCT05049850': 'kidney transplantation in highly sensitized patients',
#  'NCT05049824': 'obesity, morbid',
#  'NCT05049759': 'activity trackers and physical activity and depression and anxiety',
#  'NCT05049694': 'dentin, carious and caries active',
#  'NCT05049681': 'esophageal cancer',
#  'NCT05003687': 'healthy',
#  'NCT04806594': 'scars and acne',
#  'NCT05049603': "graves' orbitopathy",
#  'NCT05049564': 'endovascular procedures and microsurgery and intracranial aneurysm and randomized controlled trial',
#  'NCT05049473': 'unclassifiable lymphoma between dcbl and bl and burkitt lymphoma (bl) and mature b-cell leukemia burkitt type',
#  'NCT05049447': 'test anxiety and passiflora incarnata and brain activity and stress',
#  'NCT05049213': 'sars-cov 2 infection and covid19',
#  'NCT05049096': 'cardiovascular diseases and blood pressure and hypertension',
#  'NCT05049057': 'mild traumatic brain injury and posttraumatic headache',
#  'NCT05048901': 'neuroendocrine tumors,gastroenteropancreatic',
#  'NCT05049018': 'stroke',
#  'NCT05048966': "dementia and brain injury traumatic severe and brain injury traumatic moderate and alzheimer's disease and mild traumatic brain injury and traumatic brain injury",
#  'NCT05048615': 'aml',
#  'NCT05048797': 'locally advanced or metastatic non-small cell lung cancer',
#  'NCT05048628': 'hoarseness and sore throat',
#  'NCT05048589': 'influenza',
#  'NCT05048524': 'pancreas cancer and pancreatic ductal adenocarcinoma',
#  'NCT05048498': 'acute myeloid leukemia (aml) and chronic myelomonocytic leukemia (cmml) and myelodysplastic syndromes (mds)',
#  'NCT05048407': 'gynecologic cancer and cervical cancer and ovarian cancer',
#  'NCT05048368': 'advanced solid tumor and esophageal cancer',
#  'NCT05048355': 'prosthesis user and amputation',
#  'NCT05048342': 'chronic spontaneous urticaria',
#  'NCT05048160': 'advanced malignant neoplasm',
#  'NCT05048251': 'obsessive-compulsive disorder',
#  'NCT05048238': 'cle and sle and cutaneous lupus erythematosus and systemic lupus erythematosus',
#  'NCT05048017': 'pd-1 inhibitor and regorafenib and hepatocellular carcinoma',
#  'NCT05047991': 'pancreatic cancer metastatic and pancreatic cancer non-resectable',
#  'NCT05047952': 'fatigue and cognitive impairment and post-covid-19 syndrome',
#  'NCT05047939': 'anesthesia, intravenous',
#  'NCT05001984': 'icasintracranial atherosclerosis and acute ischemic stroke and intracranial atherosclerosis',
#  'NCT05047809': "wounds and hansen's disease and leprosy",
#  'NCT05047783': 'coronavirus disease 2019 and sars-cov2 infection and covid19',
#  'NCT05047744': 'validation of cmc i prosthesis in cmc i osteoarthritis',
#  'NCT05047627': 'depressive disorder and anxiety disorders and opioid-use disorder',
#  'NCT05047614': 'orthopedic disorder',
#  'NCT05047536': 'advanced/metastatic solid tumor',
#  'NCT05001971': 'small cell lung cancer',
#  'NCT05047276': 'uveal melanoma, metastatic',
#  'NCT05047198': 'ventricular tachycardia',
#  'NCT05047120': 'pain, chronic and spinal cord injuries',
#  'NCT05046912': 'psychosis',
#  'NCT05046899': 'plaque psoriasis',
#  'NCT05046834': 'chest tube removal',
#  'NCT04795128': 'hematologic malignancy',
#  'NCT05046795': 'copd',
#  'NCT05046730': 'retraction of ileostomy',
#  'NCT05046496': 'transplant renal artery stenosis',
#  'NCT05045430': 'wound',
#  'NCT05046353': 'schizo affective disorder and schizophrenia',
#  'NCT05046314': 'sarcoma, ewing',
#  'NCT05046262': 'basal cell carcinoma',
#  'NCT05046236': 'parkinson disease',
#  'NCT05046158': 'diabetic foot ulcer',
#  'NCT05046106': 'stroke, cryptogenic and stroke, embolic and stroke, cardiovascular and stroke sequelae and strokes thrombotic and stroke, ischemic and stroke',
#  'NCT05046015': 'xerosis cutis',
#  'NCT05045950': 'brain metastases',
#  'NCT05045911': 'colorectal neoplasms',
#  'NCT05045898': 'rheumatoid arthritis',
#  'NCT05045859': 'psychological trauma',
#  'NCT05045820': 'functional near-infrared spectroscopy and electroencephalography and circulating biomarkers and magnetic resonance imaging and quantitative sensory testing and acupuncture and pain and sickle cell disease',
#  'NCT05045794': 'liver failure and end stage liver disease',
#  'NCT05045781': 'healthy',
#  'NCT05045768': 'irritable bowel syndrome',
#  'NCT05045651': 'knee pain chronic and osteo arthritis knee',
#  'NCT05045612': 'respiratory tract infections and respiratory syncytial virus (rsv) and influenza and infectious disease',
#  'NCT05045599': 'reproductive behavior, family planning services',
#  'NCT05045586': 'gingival recession',
#  'NCT05045521': 'sports physical therapy',
#  'NCT05045469': 'chinese herbal medicine and rosacea',
#  'NCT05045404': 'stage ivb lung cancer ajcc v8 and stage iva lung cancer ajcc v8 and stage iv lung cancer ajcc v8 and metastatic lung non-small cell carcinoma',
#  'NCT05045326': 'mental disorder and smoking cessation and tobacco use disorder',
#  'NCT05045313': 'healthy subjects',
#  'NCT05045287': 'breast carcinoma',
#  'NCT05045274': 'left ventricular systolic dysfunction and stemist elevation myocardial infarction',
#  'NCT05045261': 'hepatitis b, chronic',
#  'NCT05045248': 'ocular myasthenia gravis and myasthenia gravis',
#  'NCT05045066': 'stage ivb prostate cancer ajcc v8 and stage iva prostate cancer ajcc v8 and stage iv prostate cancer ajcc v8 and metastatic prostate carcinoma and localized prostate carcinoma',
#  'NCT05045053': 'corneal disease',
#  'NCT04470466': 'skin lesion',
#  'NCT05044988': 'hr+/her2advanced and/or metastatic breast cancer',
#  'NCT05044962': 'hiv infections and drug-drug interaction and contraception',
#  'NCT05044936': 'muscle damage',
#  'NCT05044923': 'spinal cord injuries',
#  'NCT05044871': 'ovarian cancer',
#  'NCT05044858': 'thoracotomy and postoperative pain and pre-emptive',
#  'NCT05044806': 'acute myocardial infarction',
#  'NCT05044728': 'esophageal squamous cell carcinoma and non-small cell lung cancer',
#  'NCT05044715': 'guilt and shame and self-criticism and compassion',
#  'NCT05044702': 'low back pain',
#  'NCT05043701': 'recurrent glioblastoma',
#  'NCT05044611': 'bipolar disorder',
#  'NCT05044572': 'dyskinesias',
#  'NCT05044559': 'post-cardiac surgery',
#  'NCT04778956': 'surgery and pd-1 and nasopharyngeal carcinoma',
#  'NCT05044455': 'postpartum depression',
#  'NCT05044416': 'airway management',
#  'NCT05044364': 'hypertensive emergency',
#  'NCT05044299': 'aging and sedentary behavior',
#  'NCT05044247': 'pain, postoperative and pain, chronic',
#  'NCT05044169': 'nephrotic syndrome in children',
#  'NCT05039658': 'dlbcl',
#  'NCT05044000': 'behavior disorders and hyperphagia and sleep disorder',
#  'NCT05043987': 'gastric cancer and pancreatic cancer',
#  'NCT05043922': 'recurrent cancer and ovarian cancer',
#  'NCT05043896': 'erectile dysfunction',
#  'NCT05043857': 'pancreas cancer',
#  'NCT05043831': 'ocular hypertension and glaucoma, open-angle',
#  'NCT05043805': 'irritable mood',
#  'NCT05043766': 'healthy volunteers',
#  'NCT05043727': 'balance and parkinson disease',
#  'NCT05043714': 'epithelial tumor and metastatic cancer',
#  'NCT05043649': 'advanced soft-tissue sarcoma',
#  'NCT05043610': 'heart failure and regenerative medicine and stemi and cardiac remodeling, ventricular and myocardial infarction, anterior wall and myocardial infarction first and myocardial infarction, acute',
#  'NCT05043571': 'refractory leukemia and car t-cell-related encephalopathy syndrome and car and lymphoblastic leukemia in children and lymphoblastic leukemia, acute adult and lymphoblastic leukemia and lymphoblastic leukemia, acute, childhood',
#  'NCT05043493': 'shoulder osteoarthritis',
#  'NCT05043480': 'osteopenia or osteoporosis and sarcopenia',
#  'NCT05043441': 'psychological distress',
#  'NCT05043415': 'pancreatitis,acute necrotizing',
#  'NCT05043402': 'primary peritoneal carcinoma and fallopian tube cancer and ovarian cancer',
#  'NCT05043376': 'covid19',
#  'NCT05043350': 'covid19',
#  'NCT05043324': 'covid19',
#  'NCT05043298': 'advanced solid tumor',
#  'NCT05043207': 'hearing impairment, sensorineural and hearing loss, sensorineural',
#  'NCT05043181': 'familial hypercholesterolemia',
#  'NCT05043090': 'papillary renal cell carcinoma',
#  'NCT05042934': 'recurrent ewing sarcoma and metastatic ewing sarcoma',
#  'NCT05042895': 'infertility',
#  'NCT05042856': 'high myopia and cataract',
#  'NCT05039437': 'hypertension',
#  'NCT05042791': 'her2-positive metastatic breast cancer',
#  'NCT05042778': 'anxiety',
#  'NCT05042752': 'acute heart failure (ahf)',
#  'NCT05042726': 'drug refractory epilepsy',
#  'NCT05042713': 'postoperative pain',
#  'NCT04719884': 'perioperative complication',
#  'NCT05042700': 'low anterior resection syndrome',
#  'NCT05042661': 'irritable bowel syndrome and acupuncture-like transcutaneous electrical nerve stimulation',
#  'NCT05042648': 'patients aged between 18 and 65years undergoing total knee arthroplasty',
#  'NCT05042635': 'plaque psoriasis',
#  'NCT05042622': 'sepsis and septic shock and acute respiratory distress syndrome',
#  'NCT05042570': 'cerebral palsy',
#  'NCT05042531': 'acute myeloid leukemia',
#  'NCT05042505': 'liver transplant; complications and diabetes mellitus',
#  'NCT05042466': 'trauma, nervous system',
#  'NCT05042388': 'opioid-use disorder',
#  'NCT05041673': 'diabetes mellitus, type 2 and fatty liver, nonalcoholic',
#  'NCT05042323': 'post traumatic stress disorder',
#  'NCT05042297': 'evaluation of pr fixation in tile b2 and c1 injuries',
#  'NCT05042284': 'pain and chronic pancreatitis',
#  'NCT05042258': 'sleep disturbance and atopic dermatitis',
#  'NCT05042180': 'addiction, alcohol and alcohol dependence, in remission',
#  'NCT05041361': 'major depressive disorder',
# ...
#  'NCT05040698': 'hidradenitis suppurativa',
#  'NCT05040633': 'chronic low-back pain',
#  'NCT05040620': 'orthodontic tooth movement',
#  'NCT05040568': 'resected stage and colon cancer',
#  'NCT05040555': 'follicular lymphoma grade 3b and diffuse large b cell lymphoma',
#  'NCT05040412': 'diabetes mellitus',
#  'NCT05040490': 'postoperative pulmonary complications',
#  'NCT05040438': 'locally advanced hepatocellular carcinoma',
#  'NCT05040360': 'stage iii pancreatic neuroendocrine tumor ajcc v8 and stage ii pancreatic neuroendocrine tumor ajcc v8 and stage i pancreatic neuroendocrine tumor ajcc v8 and pancreatic neuroendocrine tumor and metastatic malignant neoplasm in the liver',
#  'NCT05040321': "dementia and alzheimer's disease (incl subtypes)",
#  'NCT05040217': "alzheimer's disease",
#  'NCT05040126': 'non-responsive multidrug-resistant pulmonary tb and treatment intolerant multidrug-resistant pulmonary tb and pre-extensively drug-resistant pulmonary tb',
#  'NCT05040087': 'type 2 diabetes',
#  'NCT05040074': 'mitral regurgitation',
#  'NCT05040061': 'generalized anxiety disorder',
#  'NCT05039411': "fistula in ano and perianal fistula due to crohn's disease",
#  'NCT05039385': 'anorexia',
#  'NCT05039801': 'stage iiia1 ovarian cancer ajcc v8 and stage ivb uterine corpus cancer ajcc v8 and stage ivb ovarian cancer ajcc v8 and stage iva uterine corpus cancer ajcc v8 and stage iva ovarian cancer ajcc v8 and stage iv uterine corpus cancer ajcc v8 and stage iv ovarian cancer ajcc v8 and stage iiic2 uterine corpus cancer ajcc v8 and stage iiic1 uterine corpus cancer ajcc v8 and stage iiic uterine corpus cancer ajcc v8 and stage iiic ovarian cancer ajcc v8 and stage iiib uterine corpus cancer ajcc v8 and stage iiib ovarian cancer ajcc v8 and stage iiia2 ovarian cancer ajcc v8 and stage iiia uterine corpus cancer ajcc v8 and stage iiia ovarian cancer ajcc v8 and stage iii uterine corpus cancer ajcc v8 and stage iii ovarian cancer ajcc v8 and refractory ovarian clear cell adenocarcinoma and refractory melanoma and refractory high grade ovarian serous adenocarcinoma and refractory head and neck squamous cell carcinoma and refractory endometrial carcinoma and pathologic stage iv cutaneous melanoma ajcc v8 and pathologic stage iiid cutaneous melanoma ajcc v8 and pathologic stage iiic cutaneous melanoma ajcc v8 and pathologic stage iiib cutaneous melanoma ajcc v8 and pathologic stage iiia cutaneous melanoma ajcc v8 and pathologic stage iii cutaneous melanoma ajcc v8 and clinical stage iv cutaneous melanoma ajcc v8 and clinical stage iii cutaneous melanoma ajcc v8 and chondrosarcoma and advanced ovarian clear cell adenocarcinoma and advanced melanoma and advanced malignant solid neoplasm and advanced head and neck squamous cell carcinoma and advanced endometrial carcinoma',
#  'NCT05039762': 'colon cancer',
#  'NCT05039736': 'liver cancer and hepatocellular carcinoma',
#  'NCT05039723': 'photoaging',
#  'NCT05039697': 'endovascular treatment and hypoxia-ischemia, brain and stroke, acute',
#  'NCT05039632': 'metastatic malignant solid neoplasm and metastatic malignant neoplasm in the lung and metastatic malignant neoplasm in the liver and advanced malignant solid neoplasm',
#  'NCT05039606': 'head and neck squamous carcinoma',
#  'NCT05039580': 'ebv infection',
#  'NCT05039567': 'coronary artery disease',
#  'NCT05039502': 'root canal infection and inflammatory response',
#  'NCT05039489': 'schizophrenia',
#  'NCT05039359': 'paroxysmal atrial fibrillation',
#  'NCT05039281': 'recurrent gliosarcoma and recurrent glioblastoma',
#  'NCT05039268': 'amyotrophic lateral sclerosis',
#  'NCT05039242': 'rheumatoid arthritis',
#  'NCT05039190': 'myasthenia gravis',
#  'NCT05039177': 'metastatic colorectal cancer',
#  'NCT05039138': 'nmt',
#  'NCT05039125': 'polycystic ovary syndrome',
#  'NCT05039060': 'diet intervention and gut microbiota and colorectal cancer',
#  'NCT05038982': 'skin diseases and chronic prurigo and chronic pruritus and pruritus and prurigo nodularis',
#  'NCT04998162': 'ankle osteoarthritis',
#  'NCT05038904': 'food allergy peanut and food allergy',
#  'NCT05038852': 'tobacco and smoking cessation',
#  'NCT05038839': 'refractory malignant solid neoplasm and advanced malignant solid neoplasm',
#  'NCT05038735': 'breast cancer',
#  'NCT05038696': 'car t-cell-related encephalopathy syndrome and car and lymphoblastic leukemia in children and lymphoblastic leukemia, acute adult and lymphoblastic leukemia and lymphoblastic leukemia, acute, childhood',
#  'NCT05038683': 'childhood overweight and obesity',
#  'NCT05038670': 'knee osteoarthritis',
#  'NCT05038657': 'urinary tract cancer and squamous cell carcinoma',
#  'NCT05038644': 't cell lymphoblastic lymphoma and t cell acute lymphoblastic leukemia and acute myeloid leukemia',
#  'NCT05038410': 'osteoarthritis',
#  'NCT05038592': 'myelodysplastic/myeloproliferative neoplasm and chronic myelomonocytic leukemia-2 and chronic myelomonocytic leukemia-1 and chronic myelomonocytic leukemia',
#  'NCT05038579': 'dementia',
#  'NCT05038527': 'adverse events and bone graft; complications and spine deformity',
#  'NCT05038488': 'stage 1 acute kidney injury and covid19',
#  'NCT05038423': 'empowerment and identification and leadership',
#  'NCT05038397': 'carcinoma, hepatocellular',
#  'NCT05038332': 'prostate cancer',
#  'NCT05038319': 'glue; dependence',
#  'NCT05038202': 'allergic rhinitis',
#  'NCT05038150': 'advanced solid tumor',
#  'NCT05038072': 'retinal vein occlusion and macular edema',
#  'NCT05038046': 'diabetes mellitus nephropathy',
#  'NCT05038007': 'anesthesia, local and blockades neuromuscular and video assisted thoracoscopic surgery and lung cancer and postoperative pain',
#  'NCT05037968': 'leg pain and/or back pain and spine fusion and degenerative disc disease',
#  'NCT05037253': 'covid-19 respiratory infection',
#  'NCT05037812': 'tibial plateau fractures',
#  'NCT05037760': 'myelofibrosis',
#  'NCT05037734': 'knee pain chronic and varus deformity and traumatic arthritis and osteoarthritis and degenerative joint disease of knee',
#  'NCT05037591': 'diabetes and aging and obesity',
#  'NCT05037526': 'gestational diabetes',
#  'NCT05037461': 'multiple endocrine neoplasia type 1 and neuroendocrine tumor of pancreas',
#  'NCT05037370': 'refractive surgery',
#  'NCT05037344': 'psychotherapy intervention evaluation',
#  'NCT05037279': 'bladder cancer and non-invasive bladder urothelial carcinoma and urothelial carcinoma recurrent and urothelial carcinoma bladder and neoplasm recurrence and bladder cancer recurrent',
#  'NCT05037175': 'posttraumatic stress disorder',
#  'NCT05037162': 'corona virus infection and covid19',
#  'NCT05037097': 'corona virus infection and sars-cov-2 infection and covid-19',
#  'NCT05037045': 'type 2 diabetes mellitus',
#  'NCT05037006': 'neuromuscular blockade, residual and neuromuscular blockade',
#  'NCT05035914': 'advanced colorectal cancer',
#  'NCT05036837': 'medication related osteonecrosis of the jaw',
#  'NCT05036772': 'anxiety and pain and virtual reality and virtual reality exposure therapy and salpingography',
#  'NCT04882176': 'advanced tumours',
#  'NCT05036681': 'endometrial carcinoma and endometrium cancer and metastatic cancer',
#  'NCT05035888': 'adverse effect',
#  'NCT05036603': 'hyaline membrane disease and chronic liver disease and lobar collapse and pneumonia neonatal and atelectasis neonatal and neonatal respiratory failure and oxygen toxicity and mechanical ventilation pressure high and mechanical ventilation complication and respiratory distress syndrome and bronchopulmonary dysplasia and premature and preterm birth',
#  'NCT05036538': 'postoperative delirium and postoperative cognitive dysfunction and preoperative stress',
#  'NCT05036512': 'sickle cell disease',
#  'NCT05036499': 'alcohol abuse and chronic pain and alcohol problem',
#  'NCT05036434': 'adrenocortical carcinoma',
#  'NCT04972175': 'type1 diabetes mellitus',
#  'NCT05036369': 'constipation chronic idiopathic',
#  'NCT05036317': 'postprandial hypoglycemia',
#  'NCT05036200': 'telangiectasia',
#  'NCT05036109': 'colon cancer and colorectal cancer',
#  'NCT05036018': 'aortic valve stenosis',
#  'NCT05035979': 'acne vulgaris',
#  'NCT05035927': 'hyperphagia',
#  'NCT05035849': 'type 2 diabetes',
#  'NCT05035836': 'her2-positive and breast cancer',
#  'NCT05035810': 'osteoarthritis of the knee',
#  'NCT05035797': 'critical illness',
#  'NCT05035745': 'metastatic triple negative breast cancers and advanced triple negative breast cancers and advanced refractory solid tumors',
#  'NCT05035706': 'recurrent acute myeloid leukemia and myeloid leukemia and acute myeloid leukemia',
#  'NCT05035693': 'radiculopathy and stenoses, spinal and herniated cervical disc and discopathy',
#  'NCT05035654': 'chronic sinusitis, ethmoidal',
#  'NCT05035641': 'renal anemia',
#  'NCT05035576': 'covid19',
#  'NCT05035563': 'covid19 and mechanical ventilation and critical illness',
#  'NCT05035524': 'covid-19 acute respiratory distress syndrome and covid19 and covid-19 pneumonia',
#  'NCT05035498': 'hemodynamic instability',
#  'NCT05035485': 'hemodynamic instability',
#  'NCT05035472': 'adverse effect',
#  'NCT05035446': 'surgery',
#  'NCT05035394': 'istent inject w and goniotomy and migs and kahook dual blade glide and cataract and open angle glaucoma',
#  'NCT05035368': 'type i diabetes',
#  'NCT05035316': 'bipolar disorder',
#  'NCT05035264': 'airway management',
#  'NCT05035147': 'pancreatic cancer',
#  'NCT05035121': 'sarcopenia',
#  'NCT05035108': 'hepatoma resectable',
#  'NCT05035069': 'anesthesia, general',
#  'NCT05035030': 'alagille syndrome',
#  'NCT05034965': 'changes in facial muscles following filler injection',
#  'NCT05034939': 'arteriovenous fistula stenosis',
#  'NCT05034887': 'gastroesophageal junction adenocarcinoma and gastric adenocarcinoma',
#  'NCT05034809': 'dengue fever with warning signs',
#  'NCT05034757': 'rotator cuff lesions',
#  'NCT05034692': 'colon neoplasm',
#  'NCT05034627': 'stage iib pancreatic cancer ajcc v8 and stage iia pancreatic cancer ajcc v8 and stage ii pancreatic cancer ajcc v8 and metastatic pancreatic adenocarcinoma and locally advanced pancreatic adenocarcinoma and stage iv pancreatic cancer ajcc v8 and stage iii pancreatic cancer ajcc v8',
#  'NCT05034536': 'metastatic melanoma',
#  'NCT05034510': "parkinson's disease",
#  'NCT05034497': 'leptomeningeal metastasis',
#  'NCT05034458': "crohn's disease",
#  'NCT05034432': 'cardiomyopathies and arrythmia',
#  'NCT05034341': 'functional outcome and nutritional supplementation and prehabilitation and frailty and spinal fusion and lumbar spine injury',
#  'NCT05034120': 'healthy',
#  'NCT05034237': 'changes in bacterial count in axilla after laser hair removal',
#  'NCT05034211': 'pain, labor and epidural and labor pain',
#  'NCT05034133': 'limited stage small cell lung cancer',
#  'NCT05034055': 'non-small cell lung cancer',
#  'NCT05034016': 'high myopia and macular schisis',
#  'NCT05034003': 'dental caries in children',
#  'NCT05033977': 'knee osteoarthritis',
#  'NCT05033769': 'breast cancer metastatic and neoplasm, breast and breast cancer female',
#  'NCT05033938': 'distal radius fracture',
#  'NCT05033873': 'chronic stroke',
#  'NCT05033808': 'sepsis',
#  'NCT05033756': 'breast cancer and malignant neoplasm of breast',
#  'NCT05033743': 'recurrent bacterial vaginosis',
#  'NCT05033730': 'trachea and ventilation therapy; complications',
#  'NCT05033717': 'bicipital tendinitis',
#  'NCT05033587': 'mgmt-unmethylated glioblastoma',
#  'NCT05033522': 'hepatocellular carcinoma',
#  'NCT05033444': 'traumatic brain injury (tbi)',
#  'NCT05033418': 'chronic pain and insomnia',
#  'NCT05033392': 'stomach neoplasms',
#  'NCT05033340': 'crohn disease',
#  'NCT05033327': 'hepatic encephalopathy and cirrhosis, liver',
#  'NCT05033197': 'motor activity',
#  'NCT05033171': 'scoliosis, severe and scoliosis idiopathic',
#  'NCT05033145': 'covid-19',
#  'NCT05033106': 'retinopathy of prematurity both eyes',
#  'NCT05033093': 'postoperative pain',
#  'NCT05033028': 'opioid-use disorder',
#  'NCT05032924': 'rotator cuff lesions',
#  'NCT05032781': 'stroke, ischemic',
#  'NCT05032742': 'stress',
#  'NCT05032716': 'children with acute lymphoblastic leukemia',
#  'NCT05032638': 'stroke',
#  'NCT05032547': 'mental health issue',
#  'NCT05032534': 'constipationfunctional and fecal incontinence',
#  'NCT05032482': 'alzheimer disease',
#  'NCT05032417': 'chronic kidney diseases',
#  'NCT05031052': 'graft dysfunction and kidney failure and kidney transplant; complications',
#  'NCT05032248': 'behcet syndrome and oral ulcer',
#  'NCT05032183': 'refractory t acute lymphoblastic leukemia and refractory lymphoblastic lymphoma and refractory b acute lymphoblastic leukemia and recurrent t acute lymphoblastic leukemia and recurrent b acute lymphoblastic leukemia and recurrent adult lymphoblastic lymphoma',
#  'NCT04885972': 'knee pain chronic and knee osteoarthritis and osteoarthritis, knee',
#  'NCT05032157': 'chronic spontaneous urticaria',
#  'NCT05032131': 'inclusion body myositis',
#  'NCT05032040': 'metastatic castration-resistant prostate cancer (mcrpc) and cervical carcinoma and endometrial cancer and clear cell carcinoma and ovarian cancer',
#  'NCT05031975': 'colorectal cancer',
#  'NCT05031936': 'vascular complications',
#  'NCT05031793': 'sleep disorder and allergic rhinitis',
#  'NCT05031780': 'sickle cell disease',
#  'NCT05031728': 'posttraumatic stress disorder (ptsd)',
#  'NCT05031689': 'melasma',
#  'NCT05031624': 'healthy subjects',
#  'NCT05031572': 'diabetes type 2 and insulin sensitivity/resistance and obesity',
#  'NCT05031533': 'non-small cell lung cancer stage ii and non-small cell lung cancer stage iii',
#  'NCT05031416': 'smoking cessation',
#  'NCT05031403': 'parkinson disease and multiple sclerosis and stroke',
#  'NCT05031390': 'femoroacetabular impingement',
#  'NCT05031351': 'als',
#  'NCT05031312': 'superior oblique palsy',
#  'NCT05031234': 'colectomy',
#  'NCT05031169': 'recession',
#  'NCT05031143': 'vogt koyanagi harada disease',
#  'NCT05031104': 'polyarticular jca and muscle weakness and fatigue and chronic knee pain and rheumatic diseases and juvenile idiopathic arthritis',
#  'NCT05030987': 'hypertension, renal and heart failure with preserved ejection fraction',
#  'NCT05030831': 'generalized arterial calcification of infancy and pseudoxanthoma elasticum and atp-binding cassette subfamily c member 6 deficiency',
#  'NCT05030779': 'systemic lupus erythematosus and autoimmune diseases',
#  'NCT05030688': 'hip arthropathy and hip injuries and hip fractures',
#  'NCT04852939': 'adhesive capsulitis',
#  'NCT05030675': 'refractory myelodysplastic syndrome and refractory chronic myelomonocytic leukemia',
#  'NCT05030662': 'knee osteoarthritis and replacement and arthroplasty',
#  'NCT05030610': 'depressive symptoms and depression and autism spectrum disorder',
#  'NCT05030545': 'hypertension and primary aldosteronism',
#  'NCT05030467': 'blood pressure and hypertension',
#  'NCT05030428': 'atherosclerotic cardiovascular disease',
#  'NCT05030415': 'lichen planopilaris and lichen planus and lichen planus scalp',
#  'NCT05030402': 'tendinosis',
#  'NCT05030389': 'healthy aging',
#  'NCT05030077': 'antineoplastic agents and gemcitabine and carboplatin and cisplatin and urogenital neoplasms and anlotinib and urothelial carcinoma',
#  'NCT05030324': 'acute viral upper respiratory infections and viral respiratory infection and influenza',
#  'NCT05030311': 'chronic spontaneous urticaria',
#  'NCT05030285': 'anxiety and cognitive impairment and psychotherapy',
#  'NCT05030246': 'primary peritoneal cancer and refractory metastatic digestive system carcinoma',
#  'NCT05030168': 'hemodialysis and kidney function',
#  'NCT05030155': 'eosinophilic granulomatosis with polyangiitis',
#  'NCT05030142': 'acute ischemic stroke (ais) related to a distal occlusion',
#  'NCT05030129': 'fragile x syndrome',
#  'NCT05030090': 'nutrition aspect of cancer and cancer of liver and cancer of colon and malnutrition',
#  'NCT05030064': 'ulcerative colitis',
#  'NCT05030051': 'skin aging',
#  'NCT05030025': 'hiv-1-infection',
#  'NCT05030012': 'bronchopulmonary dysplasia and oxygen saturation and neonatal respiratory distress and infant, premature',
#  'NCT05029999': 'metastatic triple negative breast cancer',
#  ...}

# %%
# For the nct id that does not have a condition in conditions.txt, 'title' would be added to the content column
ids = list(set(ndf['nct_id'].values.tolist()))
nctid_names_dict_keys = nctid_names_dict.keys()
tol = len(ids)
i = 0
for id in ids:
    ndf = ndf.append({'nct_id': id, 'type': 't', 'cleaned_description': nctid_names_dict[id] if id in nctid_names_dict_keys else 'title'}, ignore_index = True)
    i += 1
    if i%10000 == 0:
        print(f'processing {i}/{tol}')
# Out:
# processing 10000/130396
# processing 20000/130396
# processing 30000/130396
# processing 40000/130396
# processing 50000/130396
# processing 60000/130396
# processing 70000/130396
# processing 80000/130396
# processing 90000/130396
# processing 100000/130396
# processing 110000/130396
# processing 120000/130396
# processing 130000/130396

# %%
ndf = ndf.sort_values(['nct_id', 'type'],ascending=False)

# %%
compression_opts = dict(method='zip', archive_name='PubTator_cleaned_des.tsv')
ndf.to_csv('out.zip', sep='|', index=False, header=False, compression=compression_opts)
